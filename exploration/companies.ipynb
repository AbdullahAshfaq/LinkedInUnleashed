# %%
import pandas as pd
import os
import json

# %% [markdown]
# # Companies JSON

# %%
company_profiles = '../../data/companies/us_companies_proxycurl/10000_united_states_companies_profiles.txt'

profile_lst = []
with open(company_profiles, 'r') as f:
    profile_lst = f.readlines()

profile_lst[:2]
# Out:
# ['{"linkedin_internal_id": "1415096", "description": "\\u201947 is a sports lifestyle brand founded in Boston, MA, by twin brothers, Arthur and Henry D\\u2019Angelo in 1947. The D\\u2019Angelos were entrepreneurial pioneers who were quick to see the future of sports licensing by selling pennants and other sports memorabilia on the streets around Fenway Park. Through a combination of hard work, sound instincts, and incredible passion, the brothers grew their business from a single street cart to a premier sports lifestyle brand that uniquely melds sport and style. \\r\\n\\r\\n\\u201947 is a proud partner of the MLB, NFL, NHL, NBA, MLS, MLL, and over 900 collegiate programs.", "website": "http://www.47brand.com/", "industry": "Apparel & Fashion", "company_size": [201, 500], "company_size_on_linkedin": 272, "hq": {"country": "US", "city": "Westwood", "postal_code": "02090", "line_1": "15 SW Park", "is_hq": true, "state": "Massachusetts"}, "company_type": "PRIVATELY_HELD", "founded_year"
# ...

# %%
for i,p in enumerate(profile_lst):
    profile_lst[i] = json.loads(profile_lst[i])
# profile_lst[0]

# %%
us_companies_df = pd.DataFrame(profile_lst)
us_companies_df.head()
# Out:
#   linkedin_internal_id                                        description  \
# 0              1415096  ’47 is a sports lifestyle brand founded in Bos...
# 1              6579667  à la Sparke is an online 'a la carte' event st...
# 2             11253763  Mission: Étoile Academy Charter School ensures...
# 3              3575650  Älsa is a great-tasting, twice-daily solution ...
# 4             18450472  δ-sidereal is a research syndicate interested ...
#
#                      website                      industry company_size  \
# 0    http://www.47brand.com/             Apparel & Fashion   [201, 500]
# 1                       None                        Design      [1, 10]
# 2  http://etoileacademy.org/          Education Management      [1, 10]
# 3  http://www.alsaenergy.com  Health, Wellness and Fitness      [1, 10]
# 4     http://sidereal.center                        Design      [1, 10]
#
#    company_size_on_linkedin  \
# 0                     272.0
# ...

# %%
us_companies_df.dtypes
# Out:
# linkedin_internal_id           object
# description                    object
# website                        object
# industry                       object
# company_size                   object
# company_size_on_linkedin      float64
# hq                             object
# company_type                   object
# founded_year                  float64
# specialities                   object
# locations                      object
# name                           object
# tagline                        object
# universal_name_id              object
# profile_pic_url                object
# background_cover_image_url     object
# search_id                      object
# similar_companies              object
# updates                        object
# follower_count                float64
# dtype: object

# %%
cols_df = obj_types(us_companies_df)
cols_df
# Out:
#                          index       0  max_len
# 0         linkedin_internal_id  object        8
# 1                  description  object     3652
# 2                      website  object      208
# 3                     industry  object       36
# 4                 company_size  object        2
# 5                           hq  object        6
# 6                 company_type  object       23
# 7                 specialities  object      112
# 8                    locations  object      100
# 9                         name  object      154
# 10                     tagline  object      120
# 11           universal_name_id  object      279
# 12             profile_pic_url  object      534
# 13  background_cover_image_url  object      532
# 14                   search_id  object      143
# 15           similar_companies  object       10
# 16                     updates  object       12

# %% [markdown]
# # Comapnies csv

# %%
import pandas as pd
import json

# %%
companies_csv = '../../data/companies/company+jobs/company_details/companies.csv'

cmp_df = pd.read_csv(companies_csv)
cmp_df.dtypes
# Out:
# company_id        int64
# name             object
# description      object
# company_size    float64
# state            object
# country          object
# city             object
# zip_code         object
# address          object
# url              object
# dtype: object

# %%
def obj_types(jobs_df):
    c = jobs_df.dtypes
    cols_df = c.reset_index()
    # cols_df.columns
    cols_df = cols_df[cols_df[0]=='object'].reset_index()
    cols_df = cols_df.drop('level_0', axis=1)
    cols_df['max_len'] = 0

    counter = 0
    for i,row in cols_df.iterrows():
        # print(i,row[0])
        # print( max(jobs_df[row['index']].str.len()))
        cols_df.iloc[i,2] = max(jobs_df[row['index']].str.len()) # Max string length of col

    return cols_df

cols_df = obj_types(cmp_df)
cols_df
# Out:
#          index       0  max_len
# 0         name  object       96
# 1  description  object     3558
# 2        state  object       26
# 3      country  object        2
# 4         city  object      107
# 5     zip_code  object       42
# 6      address  object      101
# 7          url  object      150

# %%
companies_csv = '../../data/companies/company+jobs/company_details/company_industries.csv'

cmp_df = pd.read_csv(companies_csv)
cmp_df.dtypes
# Out:
# company_id     int64
# industry      object
# dtype: object

# %%
cols_df = obj_types(cmp_df)
cols_df
# Out:
#       index       0  max_len
# 0  industry  object       53

# %%
companies_csv = '../../data/companies/company+jobs/company_details/company_specialities.csv'

cmp_df = pd.read_csv(companies_csv)
cmp_df.dtypes
# Out:
# company_id     int64
# speciality    object
# dtype: object

# %%
cols_df = obj_types(cmp_df)
cols_df
# Out:
#         index       0  max_len
# 0  speciality  object     1187

# %%
companies_csv = '../../data/companies/company+jobs/company_details/employee_counts.csv'

cmp_df = pd.read_csv(companies_csv)
cmp_df.dtypes
# Out:
# company_id          int64
# employee_count      int64
# follower_count      int64
# time_recorded     float64
# dtype: object

# %%
cols_df = obj_types(cmp_df)
cols_df
# Out:
# Empty DataFrame
# Columns: [index, 0, max_len]
# Index: []
